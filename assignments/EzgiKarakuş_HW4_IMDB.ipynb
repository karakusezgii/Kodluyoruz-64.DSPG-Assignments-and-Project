# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
imdb = pd.read_csv("D:\\DATA\\imdb_dataset\\movie_metadata.csv")
pd.set_option('display.max_columns', None)
imdb.head(5)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
imdb.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
imdb.shape
# Out:
# (5043, 28)

# %%
imdb.isna().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
imdb.isna().sum() / imdb.shape[0] *100
# Out:
# color                         0.376760
# director_name                 2.062265
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_2_name                  0.257783
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# genres                        0.000000
# actor_1_name                  0.138806
# movie_title                   0.000000
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# actor_3_name                  0.456078
# facenumber_in_poster          0.257783
# plot_keywords                 3.033908
# movie_imdb_link               0.000000
# num_user_for_reviews          0.416419
# language                      0.237954
# country                       0.099147
# content_rating                6.008328
# budget                        9.756098
# title_year                    2.141582
# ...

# %%
imdb.dropna()
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %%
imdb_clean = imdb.dropna()

# %%
imdb_clean.head(5)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
imdb_clean.isna().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %%
imdb_clean.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
imdb_clean.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
imdb_clean["country"].head()
# Out:
# 0    USA
# 1    USA
# 2     UK
# 3    USA
# 5    USA
# Name: country, dtype: object

# %%
type(imdb_clean["country"])
# Out:
# pandas.core.series.Series

# %%
imdb_clean[["country"]].head()
# Out:
#   country
# 0     USA
# 1     USA
# 2      UK
# 3     USA
# 5     USA

# %%
type(imdb_clean[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
imdb_clean[["country","duration","genres","movie_title","imdb_score", "gross"]].head()
# Out:
#   country  duration                           genres  \
# 0     USA     178.0  Action|Adventure|Fantasy|Sci-Fi
# 1     USA     169.0         Action|Adventure|Fantasy
# 2      UK     148.0        Action|Adventure|Thriller
# 3     USA     164.0                  Action|Thriller
# 5     USA     132.0          Action|Adventure|Sci-Fi
#
#                                  movie_title  imdb_score        gross
# 0                                    Avatar          7.9  760505847.0
# 1  Pirates of the Caribbean: At World's End          7.1  309404152.0
# 2                                   Spectre          6.8  200074175.0
# 3                     The Dark Knight Rises          8.5  448130642.0
# 5                               John Carter          6.6   73058679.0

# %%
imdb_organized = imdb_clean[["country","duration","genres","movie_title","imdb_score", "gross"]]

# %%
imdb_organized.head(10)
# Out:
#    country  duration                                             genres  \
# 0      USA     178.0                    Action|Adventure|Fantasy|Sci-Fi
# 1      USA     169.0                           Action|Adventure|Fantasy
# 2       UK     148.0                          Action|Adventure|Thriller
# 3      USA     164.0                                    Action|Thriller
# 5      USA     132.0                            Action|Adventure|Sci-Fi
# 6      USA     156.0                           Action|Adventure|Romance
# 7      USA     100.0  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8      USA     141.0                            Action|Adventure|Sci-Fi
# 9       UK     153.0                   Adventure|Family|Fantasy|Mystery
# 10     USA     183.0                            Action|Adventure|Sci-Fi
#
#                                   movie_title  imdb_score        gross
# 0                                     Avatar          7.9  760505847.0
# ...

# %%
## ILOC - LOC
****

## iloc --> index mantığıyla çalışır. iloc[0] (girdi sırasına göre) POSITION BASED
## loc --> label numarası yazarak da istediğimize erişebiliriz. (etikete göre) LABEL BASED

****
# Out:
#   File "<ipython-input-23-8a22365a15ae>", line 2
#     ****
#     ^
# SyntaxError: invalid syntax

# %%
imdb_organized.iloc[0]

# %%
imdb_organized.loc[0]

# %%
imdb_organized.loc[2]

# %%
imdb_organized.iloc[:3]

# %%
imdb_organized["country"].value_counts().head(10)

# %%
imdb_organized["genres"].value_counts().shape

# %%
imdb_organized["genres"].unique
# Out:
# <bound method Series.unique of 0           Action|Adventure|Fantasy|Sci-Fi
# 1                  Action|Adventure|Fantasy
# 2                 Action|Adventure|Thriller
# 3                           Action|Thriller
# 5                   Action|Adventure|Sci-Fi
#                        ...
# 5026                    Drama|Music|Romance
# 5027                                  Drama
# 5033                  Drama|Sci-Fi|Thriller
# 5035    Action|Crime|Drama|Romance|Thriller
# 5042                            Documentary
# Name: genres, Length: 3756, dtype: object>

# %%
imdb_organized["country"] == "UK"
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 5       False
#         ...
# 5026    False
# 5027    False
# 5033    False
# 5035    False
# 5042    False
# Name: country, Length: 3756, dtype: bool

# %%
UK_movies = imdb_organized[imdb_organized["country"] == "UK"]

# %%
UK_movies
# Out:
#      country  duration                            genres  \
# 2         UK     148.0         Action|Adventure|Thriller
# 9         UK     153.0  Adventure|Family|Fantasy|Mystery
# 12        UK     106.0                  Action|Adventure
# 30        UK     143.0         Action|Adventure|Thriller
# 79        UK     106.0    Adventure|Drama|Family|Fantasy
# ...      ...       ...                               ...
# 4755      UK      94.0             Drama|Sci-Fi|Thriller
# 4781      UK     107.0                 Drama|History|War
# 4783      UK      84.0              Comedy|Drama|Romance
# 4795      UK      91.0          Adventure|Comedy|Fantasy
# 4922      UK      97.0                     Drama|Romance
#
#                                   movie_title  imdb_score        gross
# 2                                    Spectre          6.8  200074175.0
# 9     Harry Potter and the Half-Blood Prince          7.5  301956980.0
# ...

# %%
UK_movies= UK_movies.sort_values(by = ["imdb_score"], ascending = False)

# %%
UK_movies.head(20)
# Out:
#      country  duration                                 genres  \
# 3277      UK     116.0                          Horror|Sci-Fi
# 2644      UK     227.0  Adventure|Biography|Drama|History|War
# 3079      UK     161.0               Adventure|Mystery|Sci-Fi
# 4795      UK      91.0               Adventure|Comedy|Fantasy
# 3117      UK     104.0                           Comedy|Crime
# 3017      UK     104.0                           Comedy|Crime
# 4050      UK      94.0                                  Drama
# 4585      UK      96.0    Biography|Crime|Documentary|History
# 4458      UK     120.0                           Comedy|Crime
# 4066      UK     161.0                    Adventure|Drama|War
# 3582      UK     120.0                              Drama|War
# 2614      UK     114.0           Biography|Drama|Thriller|War
# 4289      UK     100.0                    Documentary|History
# 2480      UK     121.0                      Drama|History|War
# ...

# %%
UK_movies.iloc[:3] ## ilk 3 sırayı getirdi
# Out:
#      country  duration                                 genres  \
# 3277      UK     116.0                          Horror|Sci-Fi
# 2644      UK     227.0  Adventure|Biography|Drama|History|War
# 3079      UK     161.0               Adventure|Mystery|Sci-Fi
#
#                  movie_title  imdb_score       gross
# 3277                  Alien          8.5  78900000.0
# 2644     Lawrence of Arabia          8.4   6000000.0
# 3079  2001: A Space Odyssey          8.3  56715371.0

# %%
UK_movies.loc[3]  ## baktı 3 diye bir index yokkkk !
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-4530f7061ac5> in <module>
# ...

# %%
UK_movies.loc[2607] ## index numarasını getirdi.

# %%
UK_movies.iloc[2607]  ## 2607 adet veri yok, index olarak okuyamadı.

# %%
imdb_organized[(imdb_organized["genres"] == "Comedy") & (imdb_organized["imdb_score"] >= 8.0)]
# Out:
#      country  duration  genres          movie_title  imdb_score       gross
# 4158     USA     106.0  Comedy  Young Frankenstein          8.0  86300000.0

# %%
imdb_organized[(imdb_organized["genres"] == "Comedy") & (imdb_organized["imdb_score"] >= 7.5)]
# Out:
#      country  duration  genres           movie_title  imdb_score        gross
# 1397     USA     108.0  Comedy         The Hangover          7.8  277313371.0
# 2475     USA     119.0  Comedy             Superbad          7.6  121463226.0
# 2567     USA      88.0  Comedy           Radio Days          7.6   14792779.0
# 3161     USA      89.0  Comedy         Office Space          7.8   10824921.0
# 3542     USA     102.0  Comedy   Dazed and Confused          7.7    7993039.0
# 3597     USA      90.0  Comedy         Best in Show          7.5   18621249.0
# 3925     USA      84.0  Comedy  Waiting for Guffman          7.6    2892582.0
# 3985     USA      88.0  Comedy            Airplane!          7.8   83400000.0
# 4046     USA     109.0  Comedy         Animal House          7.6  141600000.0
# 4158     USA     106.0  Comedy   Young Frankenstein          8.0   86300000.0
# 5008     USA     102.0  Comedy               Clerks          7.8    3151130.0

# %%
imdb_organized[(imdb_organized["genres"] == "Action|Sci-Fi") & (imdb_organized["imdb_score"] >= 7.0)]
# Out:
#      country  duration         genres                  movie_title  \
# 126      USA     138.0  Action|Sci-Fi         The Matrix Reloaded
# 214      USA     113.0  Action|Sci-Fi                Total Recall
# 288      USA     153.0  Action|Sci-Fi  Terminator 2: Judgment Day
# 428       UK      95.0  Action|Sci-Fi                       Dredd
# 654      USA     136.0  Action|Sci-Fi                  The Matrix
# 656      USA     113.0  Action|Sci-Fi                Total Recall
# 1122      UK      95.0  Action|Sci-Fi                       Dredd
# 3575      UK     107.0  Action|Sci-Fi              The Terminator
# 3598      UK     106.0  Action|Sci-Fi        Escape from New York
#
#       imdb_score        gross
# 126          7.2  281492479.0
# 214          7.5  119412921.0
# 288          8.5  204843350.0
# 428          7.1   13401683.0
# 654          8.7  171383253.0
# 656          7.5  119412921.0
# 1122         7.1   13401683.0
# 3575         8.1   38400000.0
# ...

# %%
imdb_organized[(imdb_organized["genres"] == "Action|Thriller") & (imdb_organized["imdb_score"] >= 7.0)]
# Out:
#      country  duration           genres             movie_title  imdb_score  \
# 3        USA     164.0  Action|Thriller  The Dark Knight Rises          8.5
# 225       UK     123.0  Action|Thriller           Jason Bourne          7.1
# 591      USA     124.0  Action|Thriller             Die Hard 2          7.1
# 1754     USA     131.0  Action|Thriller               Die Hard          8.2
# 1871  France      93.0  Action|Thriller                  Taken          7.9
#
#             gross
# 3     448130642.0
# 225   108521835.0
# 591   117541000.0
# 1754   81350242.0
# 1871  145000989.0

# %%
imdb_organized[(imdb_organized["genres"] == "Documentary") & (imdb_organized["imdb_score"] >= 7.0)]
# Out:
#      country  duration       genres                    movie_title  \
# 4024  France      80.0  Documentary         March of the Penguins
# 4200     USA     112.0  Documentary                          Fuel
# 4204     USA      80.0  Documentary     8: The Mormon Proposition
# 4566     USA      92.0  Documentary  Who Killed the Electric Car?
# 4890     USA      86.0  Documentary                          Burn
# 4933     USA      93.0  Documentary                 The Horse Boy
# 4941     USA      91.0  Documentary                    Roger & Me
#
#       imdb_score       gross
# 4024         7.6  77413017.0
# 4200         7.6    173783.0
# 4204         7.1     99851.0
# 4566         7.7   1677838.0
# 4890         7.5    111300.0
# 4933         7.4    155984.0
# 4941         7.5   6706368.0

# %%
imdb_organized[(imdb_organized["imdb_score"] >= 9.0)]
# Out:
#      country  duration                       genres  \
# 66       USA     152.0  Action|Crime|Drama|Thriller
# 1937     USA     142.0                  Crime|Drama
# 2837     USA     220.0                  Crime|Drama
# 3466     USA     175.0                  Crime|Drama
#
#                     movie_title  imdb_score        gross
# 66             The Dark Knight          9.0  533316061.0
# 1937  The Shawshank Redemption          9.3   28341469.0
# 2837    The Godfather: Part II          9.0   57300000.0
# 3466             The Godfather          9.2  134821952.0

# %%
 imdb_organized[(imdb_organized["imdb_score"] >= 9.0)]
# Out:
#      country  duration                       genres  \
# 66       USA     152.0  Action|Crime|Drama|Thriller
# 1937     USA     142.0                  Crime|Drama
# 2837     USA     220.0                  Crime|Drama
# 3466     USA     175.0                  Crime|Drama
#
#                     movie_title  imdb_score        gross
# 66             The Dark Knight          9.0  533316061.0
# 1937  The Shawshank Redemption          9.3   28341469.0
# 2837    The Godfather: Part II          9.0   57300000.0
# 3466             The Godfather          9.2  134821952.0

# %%
 imdb_organized[(imdb_organized["imdb_score"] >= 9.0)]["country"]
# Out:
# 66      USA
# 1937    USA
# 2837    USA
# 3466    USA
# Name: country, dtype: object

# %%
imdb_organized[(imdb_organized["imdb_score"] >= 8.0) | (imdb_organized["imdb_score"] <= 9.0)]
# Out:
#      country  duration                               genres  \
# 0        USA     178.0      Action|Adventure|Fantasy|Sci-Fi
# 1        USA     169.0             Action|Adventure|Fantasy
# 2         UK     148.0            Action|Adventure|Thriller
# 3        USA     164.0                      Action|Thriller
# 5        USA     132.0              Action|Adventure|Sci-Fi
# ...      ...       ...                                  ...
# 5026  France     110.0                  Drama|Music|Romance
# 5027    Iran      90.0                                Drama
# 5033     USA      77.0                Drama|Sci-Fi|Thriller
# 5035     USA      81.0  Action|Crime|Drama|Romance|Thriller
# 5042     USA      90.0                          Documentary
#
#                                     movie_title  imdb_score        gross
# 0                                       Avatar          7.9  760505847.0
# 1     Pirates of the Caribbean: At World's End          7.1  309404152.0
# ...

# %%
top_movies = imdb_organized[imdb_organized["imdb_score"] >= 8.0]

# %%
top_movies
# Out:
#      country  duration                                     genres  \
# 3        USA     164.0                            Action|Thriller
# 17       USA     173.0                    Action|Adventure|Sci-Fi
# 27       USA     147.0                    Action|Adventure|Sci-Fi
# 43       USA     103.0  Adventure|Animation|Comedy|Family|Fantasy
# 47       USA     149.0   Action|Adventure|Fantasy|Sci-Fi|Thriller
# ...      ...       ...                                        ...
# 4708     USA     215.0                  Documentary|History|Music
# 4747   Japan     202.0                     Action|Adventure|Drama
# 4795      UK      91.0                   Adventure|Comedy|Fantasy
# 4897   Italy      99.0                       Action|Drama|Western
# 4921    Iran      89.0                               Drama|Family
#
#                            movie_title  imdb_score        gross
# 3               The Dark Knight Rises          8.5  448130642.0
# ...

# %%
top_movies.shape
# Out:
# (212, 6)

# %%
top_movies = top_movies.sort_values(by =["imdb_score"], ascending = False)

# %%
top_movies
# Out:
#      country  duration                       genres  \
# 1937     USA     142.0                  Crime|Drama
# 3466     USA     175.0                  Crime|Drama
# 2837     USA     220.0                  Crime|Drama
# 66       USA     152.0  Action|Crime|Drama|Thriller
# 3355     USA     178.0                  Crime|Drama
# ...      ...       ...                          ...
# 223      USA     127.0      Adventure|Drama|Fantasy
# 2835     USA     108.0               Drama|Thriller
# 2762      UK     120.0                Drama|Romance
# 2723  France     147.0       Drama|Mystery|Thriller
# 2356     USA     236.0      Adventure|Drama|Western
#
#                     movie_title  imdb_score        gross
# 1937  The Shawshank Redemption          9.3   28341469.0
# 3466             The Godfather          9.2  134821952.0
# 2837    The Godfather: Part II          9.0   57300000.0
# 66             The Dark Knight          9.0  533316061.0
# ...

# %%
top_movies50 = top_movies.head(50)

# %%
type(top_movies50)
# Out:
# pandas.core.frame.DataFrame

# %%
type(top_movies50["country"])
# Out:
# pandas.core.series.Series

# %%
top_movies50["country"].value_counts()
# Out:
# USA            39
# Japan           3
# Italy           1
# New Zealand     1
# South Korea     1
# Iran            1
# Germany         1
# Brazil          1
# France          1
# UK              1
# Name: country, dtype: int64

# %%
count_topmovies = top_movies50["country"].value_counts()

# %%
count_topmovies
# Out:
# USA            39
# Japan           3
# Italy           1
# New Zealand     1
# South Korea     1
# Iran            1
# Germany         1
# Brazil          1
# France          1
# UK              1
# Name: country, dtype: int64

# %%
imdb_organized[(imdb_organized["genres"] == "Comedy") & (imdb_organized["imdb_score"] >= 7.5)]
# Out:
#      country  duration  genres           movie_title  imdb_score        gross
# 3597     USA      90.0  Comedy         Best in Show          7.5   18621249.0
# 2567     USA      88.0  Comedy           Radio Days          7.6   14792779.0
# 2475     USA     119.0  Comedy             Superbad          7.6  121463226.0
# 3925     USA      84.0  Comedy  Waiting for Guffman          7.6    2892582.0
# 4046     USA     109.0  Comedy         Animal House          7.6  141600000.0
# 3542     USA     102.0  Comedy   Dazed and Confused          7.7    7993039.0
# 3985     USA      88.0  Comedy            Airplane!          7.8   83400000.0
# 1397     USA     108.0  Comedy         The Hangover          7.8  277313371.0
# 3161     USA      89.0  Comedy         Office Space          7.8   10824921.0
# 5008     USA     102.0  Comedy               Clerks          7.8    3151130.0
# 4158     USA     106.0  Comedy   Young Frankenstein          8.0   86300000.0

# %%
comedy_movies = (imdb_organized[(imdb_organized["genres"] == "Comedy") & (imdb_organized["imdb_score"] >= 7.5)])

# %%
type(comedy_movies)
# Out:
# pandas.core.frame.DataFrame

# %%
top_movies["country"].value_counts()
# Out:
# USA             147
# UK               23
# France            7
# Germany           5
# Japan             5
# Brazil            3
# Denmark           3
# Italy             3
# Spain             2
# South Korea       2
# Iran              2
# West Germany      1
# India             1
# Israel            1
# Argentina         1
# Canada            1
# New Zealand       1
# Mexico            1
# Ireland           1
# South Africa      1
# Australia         1
# Name: country, dtype: int64

# %% [markdown]
# ## Number of Countries That IMDB Score Higher Than 8.0

# %%
plt.style.use('ggplot')
plt.figure(figsize=(13, 4))

top_movies["country"].value_counts().plot(kind='bar')

plt.xticks(rotation=45)

plt.ylabel("Number of Countries")
plt.xlabel("Country Name")

plt.title("Number of Countries That IMDB Score Higher Than 8.0 \n")
# Out:
# Text(0.5, 1.0, 'Number of Countries That IMDB Score Higher Than 8.0 \n')

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
top_movies
# Out:
#      country  duration                       genres  \
# 1937     USA     142.0                  Crime|Drama
# 3466     USA     175.0                  Crime|Drama
# 2837     USA     220.0                  Crime|Drama
# 66       USA     152.0  Action|Crime|Drama|Thriller
# 3355     USA     178.0                  Crime|Drama
# ...      ...       ...                          ...
# 223      USA     127.0      Adventure|Drama|Fantasy
# 2835     USA     108.0               Drama|Thriller
# 2762      UK     120.0                Drama|Romance
# 2723  France     147.0       Drama|Mystery|Thriller
# 2356     USA     236.0      Adventure|Drama|Western
#
#                     movie_title  imdb_score        gross
# 1937  The Shawshank Redemption          9.3   28341469.0
# 3466             The Godfather          9.2  134821952.0
# 2837    The Godfather: Part II          9.0   57300000.0
# 66             The Dark Knight          9.0  533316061.0
# ...

# %%
top_movies.shape
# Out:
# (212, 6)

# %%
gross_top =top_movies.sort_values(by='gross', ascending=False).head(10)
gross_top
# Out:
#      country  duration                                     genres  \
# 17       USA     173.0                    Action|Adventure|Sci-Fi
# 794      USA     173.0                    Action|Adventure|Sci-Fi
# 66       USA     152.0                Action|Crime|Drama|Thriller
# 3024     USA     125.0            Action|Adventure|Fantasy|Sci-Fi
# 3        USA     164.0                            Action|Thriller
# 509      USA      73.0   Adventure|Animation|Drama|Family|Musical
# 43       USA     103.0  Adventure|Animation|Comedy|Family|Fantasy
# 27       USA     147.0                    Action|Adventure|Sci-Fi
# 338      USA     100.0          Adventure|Animation|Comedy|Family
# 339      USA     192.0             Action|Adventure|Drama|Fantasy
#
#                                          movie_title  imdb_score        gross
# 17                                     The Avengers          8.1  623279547.0
# 794                                    The Avengers          8.1  623279547.0
# ...

# %% [markdown]
# ## Movie Genres with the Most Budget Spent

# %%
import seaborn as sns

plt.style.use('ggplot')

plt.figure(figsize=(9,6))  # Your code here

sns.barplot(x = gross_top["gross"] , y =gross_top["genres"]) 

plt.xticks(rotation=0)

#plt.xlim(7.0, 10.0)


plt.ylabel("Genres")
plt.title("Movie Genres with the Most Budget Spent")
# Out:
# Text(0.5, 1.0, 'Movie Genres with the Most Budget Spent')

# %%
imdb.sort_values(by = ["imdb_score"], inplace = True, ascending = False)

# %%
imdb["imdb_score"]
# Out:
# 2765    9.5
# 1937    9.3
# 3466    9.2
# 4409    9.1
# 2824    9.1
#        ...
# 2268    1.9
# 2295    1.9
# 4605    1.9
# 1136    1.7
# 2834    1.6
# Name: imdb_score, Length: 5043, dtype: float64

# %%
imdb["imdb_score"].dropna()
# Out:
# 2765    9.5
# 1937    9.3
# 3466    9.2
# 4409    9.1
# 2824    9.1
#        ...
# 2268    1.9
# 2295    1.9
# 4605    1.9
# 1136    1.7
# 2834    1.6
# Name: imdb_score, Length: 5043, dtype: float64

# %%
imdb
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 2765  Color        John Blanchard                     NaN      65.0
# 1937  Color        Frank Darabont                   199.0     142.0
# 3466  Color  Francis Ford Coppola                   208.0     175.0
# 4409    NaN        John Stockwell                     2.0      90.0
# 2824  Color                   NaN                    53.0      55.0
# ...     ...                   ...                     ...       ...
# 2268  Color       Jason Friedberg                   111.0      88.0
# 2295  Color             Bob Clark                    32.0      88.0
# 4605  Color         A. Raven Cruz                     3.0      97.0
# 1136  Color     Lawrence Kasanoff                    12.0      91.0
# 2834  Color            Jon M. Chu                    84.0     115.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 2765                      0.0                   176.0    Andrea Martin
# ...

# %%
import seaborn as sns

plt.style.use('ggplot')

plt.figure(figsize=(10,15))  # Your code here

sns.barplot(x = imdb["imdb_score"], y = imdb["country"]) 

plt.xlim(1.5, 10.0)


plt.xlabel("Imdb Score")
plt.title("IMDB SCORES OF TOP COUNTRIES")
# Out:
# Text(0.5, 1.0, 'IMDB SCORES OF TOP COUNTRIES')

# %%
top_movies[top_movies["country"] == "USA"].shape
# Out:
# (147, 6)

# %%
top_movies[top_movies["country"] == "USA"]["imdb_score"].sum() / 147
# Out:
# 8.273469387755103

# %%
top_movies[top_movies["country"] == "New Zealand"].shape
# Out:
# (1, 6)

# %%
top_movies[top_movies["country"] == "New Zealand"]["imdb_score"].sum()
# Out:
# 8.8

# %%
top_movies["country"].value_counts()
# Out:
# USA             147
# UK               23
# France            7
# Germany           5
# Japan             5
# Denmark           3
# Brazil            3
# Italy             3
# Iran              2
# South Korea       2
# Spain             2
# West Germany      1
# Israel            1
# Mexico            1
# South Africa      1
# New Zealand       1
# Argentina         1
# India             1
# Ireland           1
# Australia         1
# Canada            1
# Name: country, dtype: int64

# %%
type(top_movies["country"])
# Out:
# pandas.core.series.Series

# %%
type(top_movies["country"].value_counts())
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize=(7,5))  # Your code here

plt.style.use('ggplot')
sns.barplot(x = top_movies["country"].value_counts(), y = top_movies["country"].unique()) 

plt.xlabel("Number of Countries")
plt.ylabel("Name of Countries")

plt.title("Number of Countries with IMDB Score Higher than 8.00")
# Out:
# Text(0.5, 1.0, 'Number of Countries with IMDB Score Higher than 8.00')

# %%
imdb_organized_low = imdb_organized.sort_values ( by = ["imdb_score"], ascending = False)

# %%
imdb_organized_low
# Out:
#       country  duration                          genres  \
# 1937      USA     142.0                     Crime|Drama
# 3466      USA     175.0                     Crime|Drama
# 2837      USA     220.0                     Crime|Drama
# 66        USA     152.0     Action|Crime|Drama|Thriller
# 339       USA     192.0  Action|Adventure|Drama|Fantasy
# ...       ...       ...                             ...
# 3664      USA      95.0                    Action|Sport
# 3505      USA      93.0                    Comedy|Sport
# 2268      USA      88.0                          Comedy
# 2295  Germany      88.0            Comedy|Family|Sci-Fi
# 2834      USA     115.0               Documentary|Music
#
#                                          movie_title  imdb_score        gross
# 1937                       The Shawshank Redemption          9.3   28341469.0
# 3466                                  The Godfather          9.2  134821952.0
# ...

# %%
imdb_organized.sort_values( by = ["imdb_score"], ascending = True, inplace=True)
# Out:
# <ipython-input-119-7a4001d2fd96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_organized.sort_values( by = ["imdb_score"], ascending = True, inplace=True)

# %%
imdb_lowo = imdb_organized.head(10)

# %% [markdown]
# ## Movie Genres That Have Most Lowest Scores

# %%
plt.figure(figsize=(7,4))  
plt.style.use('ggplot')

sns.barplot(x = imdb_lowo["imdb_score"], y = imdb_lowo["genres"]) 

plt.xlabel("IMDB Score")
plt.ylabel("Genres")

plt.title("Movie Genres That Have Most Lowest Scores ")
# Out:
# Text(0.5, 1.0, 'Movie Genres That Have Most Lowest Scores ')

# %%
imdb.tail(10)
# Out:
#       color           director_name  num_critic_for_reviews  duration  \
# 2983  Color           Robert Iscove                    60.0      90.0
# 3340  Color      Vondie Curtis-Hall                    66.0     104.0
# 3664  Color  Preston A. Whitmore II                    25.0      95.0
# 1729  Color       Frédéric Auburtin                     7.0     110.0
# 3505  Color        Don Michael Paul                    25.0      93.0
# 2268  Color         Jason Friedberg                   111.0      88.0
# 2295  Color               Bob Clark                    32.0      88.0
# 4605  Color           A. Raven Cruz                     3.0      97.0
# 1136  Color       Lawrence Kasanoff                    12.0      91.0
# 2834  Color              Jon M. Chu                    84.0     115.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 2983                      7.0                   251.0      Kelly Clarkson
# ...

# %%
imdb["director_name"].value_counts()
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        17
#                     ..
# Lucrecia Martel      1
# Lluís Quílez         1
# R.J. Cutler          1
# Mikel Rueda          1
# Marc Bennett         1
# Name: director_name, Length: 2398, dtype: int64

# %%
directors = pd.DataFrame(imdb["director_name"].value_counts())

# %%
type(directors)
# Out:
# pandas.core.frame.DataFrame

# %%
directors
# Out:
#                   director_name
# Steven Spielberg             26
# Woody Allen                  22
# Martin Scorsese              20
# Clint Eastwood               20
# Ridley Scott                 17
# ...                         ...
# Lucrecia Martel               1
# Lluís Quílez                  1
# R.J. Cutler                   1
# Mikel Rueda                   1
# Marc Bennett                  1
#
# [2398 rows x 1 columns]

# %%
popular_d =directors[directors["director_name"] > 15]

# %%
popular_d
# Out:
#                    director_name
# Steven Spielberg              26
# Woody Allen                   22
# Martin Scorsese               20
# Clint Eastwood                20
# Ridley Scott                  17
# Steven Soderbergh             16
# Tim Burton                    16
# Spike Lee                     16

# %%
popular_d.reset_index(inplace=True)

# %%
popular_d
# Out:
#                index  director_name
# 0   Steven Spielberg             26
# 1        Woody Allen             22
# 2    Martin Scorsese             20
# 3     Clint Eastwood             20
# 4       Ridley Scott             17
# 5  Steven Soderbergh             16
# 6         Tim Burton             16
# 7          Spike Lee             16

# %%
popular_d = popular_d.rename(columns={'index': 'director_name', 'director_name': 'movie_number'})

# %%
popular_d
# Out:
#        director_name  movie_number
# 0   Steven Spielberg            26
# 1        Woody Allen            22
# 2    Martin Scorsese            20
# 3     Clint Eastwood            20
# 4       Ridley Scott            17
# 5  Steven Soderbergh            16
# 6         Tim Burton            16
# 7          Spike Lee            16

# %%
# df = df.set_index("blablabla")  ## blablabla'yı index yaptık.

# %%
plt.style.use('ggplot')

plt.figure(figsize=(8,4))  

sns.barplot(x = popular_d["movie_number"], y =popular_d["director_name"]) 

plt.xlabel("Movie Number of Directors")
plt.ylabel("Name of Directors")

plt.title("Popular Directors According to Number of Movie in Imdb")
# Out:
# Text(0.5, 1.0, 'Popular Directors According to Number of Movie in Imdb')
